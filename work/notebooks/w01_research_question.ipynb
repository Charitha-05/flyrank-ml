# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Charitha-05/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane: Lane 2 – Refresh / Content Opportunity Scoring
#
# I chose Lane 2 because organizations often manage thousands of webpages but have limited time and resources to review them manually. My goal is to build a machine learning system that identifies pages which are showing signs of declining search performance and prioritizes them for content review. By combining content characteristics, historical search performance, engagement metrics, and query-level behavior, the project aims to support data-driven decisions about which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Decision
#
# My work is going to improve the decision of **which webpages should be prioritized for content review and optimization** based on their search performance, engagement metrics, content characteristics, and query-level behavior. Instead of reviewing pages manually, the system helps identify pages that are most likely to benefit from attention.
#
# ### Who acts on it?
#
# The recommendations are used by the **SEO or content team**. They review the prioritized pages and decide whether to refresh, expand, rewrite, consolidate, monitor, or leave the content unchanged.
#
# ### Cost of a wrong recommendation
#
# If the system fails to recommend a high-priority page, the page may continue losing search visibility, traffic, and potential business value before it is reviewed. If the system recommends a low-priority page, the content team may spend time and resources reviewing pages that do not require immediate attention, reducing the efficiency of the optimization process.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Quick look at the data
#
# The starter dataset contains **30,000 webpages**, making manual review impractical for an SEO team. The pages have an **average of 5,200.37 impressions over the last 90 days**, indicating that many pages receive meaningful search visibility and should be monitored carefully. The **average content age is 256.17 days**, suggesting that many pages have been online long enough to potentially require review or optimization.
#
# These observations support my choice of **Lane 2 – Refresh / Content Opportunity Scoring**, where machine learning can assist the SEO team by prioritizing pages for review based on multiple observable signals rather than relying solely on manual inspection.

# %%
import pandas as pd

# Load starter dataset
df = pd.read_csv("/content_refresh_anonymized.csv")

# Real numbers from the starter dataset
num_pages = len(df)
avg_impressions = df["impressions_90d"].mean()
avg_content_age = df["content_age_days"].mean()

print(f"Number of pages: {num_pages:,}")
print(f"Average 90-day impressions: {avg_impressions:.2f}")
print(f"Average content age (days): {avg_content_age:.2f}")
# Out:
# Number of pages: 30,000
# Average 90-day impressions: 5200.37
# Average content age (days): 256.17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ## What I can claim
#
# This project aims to identify webpages that may benefit from content review based on observable search performance, engagement, and content signals. The recommendations are intended to support decision-making by ranking pages according to their predicted priority for review.
#
# ## What I cannot claim
#
# The model cannot prove that refreshing a page will improve its search ranking or traffic. It does not predict Google's ranking algorithm or establish cause-and-effect relationships. Final content decisions remain the responsibility of the SEO or content team.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
